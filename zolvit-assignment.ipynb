# %%
# !pip install fitz
# !pip install pdf2image
# !pip install requests
# !pip install pymupdf
# Out:
# Collecting fitz
#   Downloading fitz-0.0.1.dev2-py2.py3-none-any.whl.metadata (816 bytes)
# Collecting configobj (from fitz)
#   Downloading configobj-5.0.9.tar.gz (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.5/101.5 kB 2.1 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting configparser (from fitz)
#   Downloading configparser-7.1.0-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: httplib2 in /opt/conda/lib/python3.10/site-packages (from fitz) (0.21.0)
# Requirement already satisfied: nibabel in /opt/conda/lib/python3.10/site-packages (from fitz) (5.2.1)
# Collecting nipype (from fitz)
#   Downloading nipype-1.8.6-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from fitz) (1.26.4)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from fitz) (2.2.3)
# Collecting pyxnat (from fitz)
#   Downloading pyxnat-1.6.2-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from fitz) (1.14.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /opt/conda/lib/python3.10/site-packages (from httplib2->fitz) (3.1.2)
# Requirement already satisfied: packaging>=17 in /opt/conda/lib/python3.10/site-packages (from nibabel->fitz) (21.3)
# Requirement already satisfied: click>=6.6.0 in /opt/conda/lib/python3.10/site-packages (from nipype->fitz) (8.1.7)
# Requirement already satisfied: networkx>=2.0 in /opt/conda/lib/python3.10/site-packages (from nipype->fitz) (3.3)
# Collecting prov>=1.5.2 (from nipype->fitz)
#   Downloading prov-2.0.1-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: pydot>=1.2.3 in /opt/conda/lib/python3.10/site-packages (from nipype->fitz) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.2 in /opt/conda/lib/python3.10/site-packages (from nipype->fitz) (2.9.0.post0)
# Collecting rdflib>=5.0.0 (from nipype->fitz)
#   Downloading rdflib-7.1.0-py3-none-any.whl.metadata (11 kB)
# Collecting simplejson>=3.8.0 (from nipype->fitz)
#   Downloading simplejson-3.19.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Collecting traits!=5.0,<6.4,>=4.6 (from nipype->fitz)
#   Downloading traits-6.3.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: filelock>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from nipype->fitz) (3.15.1)
# Collecting etelemetry>=0.2.0 (from nipype->fitz)
#   Downloading etelemetry-0.3.1-py3-none-any.whl.metadata (3.2 kB)
# Collecting looseversion (from nipype->fitz)
#   Downloading looseversion-1.3.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->fitz) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->fitz) (2024.1)
# Requirement already satisfied: lxml>=4.3 in /opt/conda/lib/python3.10/site-packages (from pyxnat->fitz) (5.3.0)
# Requirement already satisfied: requests>=2.20 in /opt/conda/lib/python3.10/site-packages (from pyxnat->fitz) (2.32.3)
# Collecting pathlib>=1.0 (from pyxnat->fitz)
#   Downloading pathlib-1.0.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting ci-info>=0.2 (from etelemetry>=0.2.0->nipype->fitz)
#   Downloading ci_info-0.3.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting rdflib>=5.0.0 (from nipype->fitz)
#   Downloading rdflib-6.3.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.2->nipype->fitz) (1.16.0)
# Collecting isodate<0.7.0,>=0.6.0 (from rdflib>=5.0.0->nipype->fitz)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.20->pyxnat->fitz) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.20->pyxnat->fitz) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.20->pyxnat->fitz) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.20->pyxnat->fitz) (2024.8.30)
# Downloading fitz-0.0.1.dev2-py2.py3-none-any.whl (20 kB)
# Downloading configparser-7.1.0-py3-none-any.whl (17 kB)
# Downloading nipype-1.8.6-py3-none-any.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 36.3 MB/s eta 0:00:0000:0100:01
# Downloading pyxnat-1.6.2-py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.6/95.6 kB 5.9 MB/s eta 0:00:00
# Downloading etelemetry-0.3.1-py3-none-any.whl (6.4 kB)
# Downloading pathlib-1.0.1-py3-none-any.whl (14 kB)
# Downloading prov-2.0.1-py3-none-any.whl (421 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 421.5/421.5 kB 20.6 MB/s eta 0:00:00
# Downloading rdflib-6.3.2-py3-none-any.whl (528 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 528.1/528.1 kB 23.2 MB/s eta 0:00:00
# Downloading simplejson-3.19.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (137 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 8.0 MB/s eta 0:00:00
# Downloading traits-6.3.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 80.4 MB/s eta 0:00:00:00:01
# Downloading looseversion-1.3.0-py2.py3-none-any.whl (8.2 kB)
# Downloading ci_info-0.3.0-py3-none-any.whl (7.8 kB)
# Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 1.7 MB/s eta 0:00:00
# Building wheels for collected packages: configobj
#   Building wheel for configobj (pyproject.toml) ... done
#   Created wheel for configobj: filename=configobj-5.0.9-py2.py3-none-any.whl size=35615 sha256=b02412acedd095fbe7f8666f94580289332d8f7d80d4e55968a914afeb16ebbc
#   Stored in directory: /root/.cache/pip/wheels/a1/6c/03/6c5e3cf1a6e4b9e2fc5c4409be4abc5a8268bd9c878739cb32
# Successfully built configobj
# Installing collected packages: pathlib, looseversion, traits, simplejson, isodate, configparser, configobj, ci-info, rdflib, pyxnat, etelemetry, prov, nipype, fitz
# Successfully installed ci-info-0.3.0 configobj-5.0.9 configparser-7.1.0 etelemetry-0.3.1 fitz-0.0.1.dev2 isodate-0.6.1 looseversion-1.3.0 nipype-1.8.6 pathlib-1.0.1 prov-2.0.1 pyxnat-1.6.2 rdflib-6.3.2 simplejson-3.19.3 traits-6.3.2
# Requirement already satisfied: pdf2image in /opt/conda/lib/python3.10/site-packages (1.17.0)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.10/site-packages (from pdf2image) (10.3.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests) (2024.8.30)
# Collecting pymupdf
#   Downloading PyMuPDF-1.24.11-cp38-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.4 kB)
# Downloading PyMuPDF-1.24.11-cp38-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (19.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.6/19.6 MB 59.8 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: pymupdf
# Successfully installed pymupdf-1.24.11

# %%
import os
import re
import fitz
import requests
from pdf2image import convert_from_path
import glob
import csv

# %%
# Gemini API Configuration
GEMINI_API_ENDPOINT = "https://generativelanguage.googleapis.com/v1beta/models/gemini-1.5-flash-latest:generateCo"
GEMINI_API_KEY = "AIzaSyAszt14u9vObyacTUPyhEP_z-3J4yMYZpA"

# %%
def gemini_ocr(image_path):
    with open(image_path, 'rb') as image_file:
        files = {'file': image_file}
        headers = {'Authorization': f'Bearer {GEMINI_API_KEY}'}
        response = requests.post(GEMINI_API_ENDPOINT, headers=headers, files=files)
        if response.status_code == 200:
            return response.json().get("text", "")
        else:
            print(f"Error with Gemini API: {response.status_code}, {response.text}")
            return ""

def extract_text_from_pdf(file_path):
    doc = fitz.open(file_path)
    text_content = ""
    for page_num in range(doc.page_count):
        page = doc[page_num]
        text = page.get_text()
        if not text.strip():
            images = convert_from_path(file_path, first_page=page_num + 1, last_page=page_num + 1)
            temp_image_path = f"temp_page_{page_num}.png"
            images[0].save(temp_image_path, "PNG")
            text += gemini_ocr(temp_image_path)
            os.remove(temp_image_path)
        text_content += text
    doc.close()
    return text_content


def extract_fields(text_content):
    fields = {
        'invoice_number': re.search(r'Invoice #:\s*(INV-\d+)', text_content),
        'invoice_date': re.search(r'Invoice Date:\s*(\d{1,2} \w+ \d{4})', text_content),
        #'customer_name': re.search(r'Customer Details:\s*(.+?)\n', text_content),
        #'due_date': re.search(r'Due Date:\s*(\d{1,2} \w+ \d{4})', text_content),
        'taxable_value': re.search(r'Taxable Amount\s*₹([\d,.]+)', text_content),
        'sgst_amount': re.search(r'SGST\s*\d+\.?\d*%\s*₹([\d,.]+)', text_content),
        'cgst_amount': re.search(r'CGST\s*\d+\.?\d*%\s*₹([\d,.]+)', text_content),
        'igst_amount': re.search(r'IGST\s*\d+\.?\d*%\s*₹([\d,.]+)', text_content),  # Add this in case IGST is applicable
        'sgst_rate': re.search(r'SGST\s*(\d+\.?\d*)%', text_content),
        'cgst_rate': re.search(r'CGST\s*(\d+\.?\d*)%', text_content),
        'igst_rate': re.search(r'IGST\s*(\d+\.?\d*)%', text_content),  # Add this in case IGST is applicable
        'tax_amount': re.search(r'Taxable Amount\s*₹[\d,.]+\n.*?([\d,.]+)\s*\(Total Tax\)', text_content),  # To capture total tax
        'tax_rate': re.search(r'Total Tax\s*(\d+\.?\d*)%', text_content),  # Extract total tax rate
        'final_amount': re.search(r'Total\s*₹([\d,.]+)', text_content),
        #'total_discount': re.search(r'Total Discount\s*₹([\d,.]+)', text_content),
        #'amount_in_words': re.search(r'Total amount \(in words\):\s*([A-Za-z\s,-]+)', text_content),
        #'account_number': re.search(r'Account #:\s*(\d+)', text_content),
        #'ifsc_code': re.search(r'IFSC Code:\s*([A-Za-z0-9]+)', text_content),
        'place_of_supply': re.search(r'Place of Supply:\s*(\d{2}-[A-Za-z\s]+)', text_content),
        # Extracting Place of Origin from the Supplier's GSTIN
        'place_of_origin': re.search(r'GSTIN\s*(\d{2})', text_content),  # First two digits of GSTIN indicate the state
        'gstin_supplier': re.search(r'GSTIN\s*([A-Za-z0-9]+)', text_content),  # GSTIN of supplier
        'gstin_recipient': re.search(r'GSTIN Recipient\s*([A-Za-z0-9]+)', text_content)  # GSTIN of recipient
    }
    
    # Mapping state codes to state names
    state_codes = {
        '01': 'Jammu & Kashmir', '02': 'Himachal Pradesh', '03': 'Punjab', '04': 'Chandigarh',
        '05': 'Uttarakhand', '06': 'Haryana', '07': 'Delhi', '08': 'Rajasthan', '09': 'Uttar Pradesh',
        '10': 'Bihar', '11': 'Sikkim', '12': 'Arunachal Pradesh', '13': 'Nagaland', '14': 'Manipur',
        '15': 'Mizoram', '16': 'Tripura', '17': 'Meghalaya', '18': 'Assam', '19': 'West Bengal',
        '20': 'Jharkhand', '21': 'Odisha', '22': 'Chhattisgarh', '23': 'Madhya Pradesh', '24': 'Gujarat',
        '25': 'Daman and Diu', '26': 'Dadra and Nagar Haveli', '27': 'Maharashtra', '28': 'Andhra Pradesh',
        '29': 'Karnataka', '30': 'Goa', '31': 'Lakshadweep', '32': 'Kerala', '33': 'Tamil Nadu',
        '34': 'Puducherry', '35': 'Andaman and Nicobar Islands', '36': 'Telangana', '37': 'Andhra Pradesh (New)',
        '38': 'Ladakh', '97': 'Other Territory'
    }
    
    extracted_fields = {k: v.group(1) if v else None for k, v in fields.items()}
    
    # Translate GSTIN origin code to state
    extracted_fields['place_of_supply'] = extracted_fields['place_of_supply'][:-1]
    gstin_code = extracted_fields.get('place_of_origin')
    if gstin_code in state_codes:
        extracted_fields['place_of_origin'] = str(gstin_code)+"-"+state_codes[gstin_code]
        
    # Replace None values with 'NULL' and handle lists of values
    for key, value in extracted_fields.items():
        if isinstance(value, list):
            extracted_fields[key] = [item if item else "" for item in value]  # Replace None in lists with 'NULL'
        elif value is None:
            extracted_fields[key] = ""  # Replace None with 'NULL'
    
    return extracted_fields



# def determine_trust(fields):
#     checks = {
#         'invoice_number': lambda x: bool(re.match(r'INV-\d+', x)) if x else False,
#         'invoice_date': lambda x: bool(re.match(r'\d{1,2} \w+ \d{4}', x)) if x else False,
#         'final_amount': lambda x: bool(re.match(r'^\d+[\d,.]*$', x)) if x else False
#     }
#     total_checks = len(checks)
#     trust_score = sum(1 for key, check in checks.items() if check(fields.get(key)))
#     return (trust_score / total_checks) * 100



def determine_trust(fields):
    checks = {
        # Check if invoice number is in the format 'INV-' followed by digits
        'invoice_number': lambda x: bool(re.match(r'INV-\d+', x)) if x else False,
        
        # Check if invoice date matches the expected date format
        'invoice_date': lambda x: bool(re.match(r'\d{1,2} \w+ \d{4}', x)) if x else False,
        
        # Check if taxable value is a valid number (e.g., 1234.56)
        'taxable_value': lambda x: bool(re.match(r'^\d+[\d,.]*$', x)) if x else False,
        
        # Check if SGST, CGST, IGST amounts are valid numbers (can be empty if not applicable)
        'sgst_amount': lambda x: bool(re.match(r'^\d+[\d,.]*$', x)) if x else True,
        'cgst_amount': lambda x: bool(re.match(r'^\d+[\d,.]*$', x)) if x else True,
        'igst_amount': lambda x: bool(re.match(r'^\d+[\d,.]*$', x)) if x else True,
        
        # Check if SGST, CGST, IGST rates are valid percentages (can be empty if not applicable)
        'sgst_rate': lambda x: bool(re.match(r'^\d+\.?\d*$', x)) if x else True,
        'cgst_rate': lambda x: bool(re.match(r'^\d+\.?\d*$', x)) if x else True,
        'igst_rate': lambda x: bool(re.match(r'^\d+\.?\d*$', x)) if x else True,
        
        # Check if the final amount is a valid number
        'final_amount': lambda x: bool(re.match(r'^\d+[\d,.]*$', x)) if x else False,
        
        # Check if place of supply is in the correct format (e.g., 23-MADHYA PRADESH)
        'place_of_supply': lambda x: bool(re.match(r'^\d{2}-[A-Za-z\s]+$', x)) if x else False,
        
        # Check if place of origin (extracted from GSTIN) is in the correct format (e.g., 23-Madhya Pradesh)
        'place_of_origin': lambda x: bool(re.match(r'^\d{2}-[A-Za-z\s]+$', x)) if x else False,
        
        # Check if GSTIN supplier is in the correct format (15 characters alphanumeric)
        'gstin_supplier': lambda x: bool(re.match(r'^[A-Za-z0-9]{15}$', x)) if x else False,
        
        # GSTIN recipient can be optional, but if present, check for valid format
        'gstin_recipient': lambda x: bool(re.match(r'^[A-Za-z0-9]{15}$', x)) if x else True
    }

    total_checks = len(checks)
    trust_score = sum(1 for key, check in checks.items() if check(fields.get(key)))
    
    # Return trust score as a percentage
    return (trust_score / total_checks) * 100


def generate_report(directory, output_csv):
    with open(output_csv, mode='w', newline='') as csv_file:
        #fieldmanes = []
        fieldnames = ['file', 'taxable_value', 'sgst_amount', 'cgst_amount', 'igst_amount', 'sgst_rate', 'cgst_rate',
              'igst_rate', 'tax_amount', 'tax_rate', 'final_amount','invoice_number', 'invoice_date',
              'place_of_supply', 'place_of_origin', 'gstin_supplier', 'gstin_recipient', 'trust_score']

        #fieldnames = ['file', 'invoice_number', 'invoice_date', 'customer_name', 'due_date', 'taxable_amount', 'cgst', 'sgst', 'total_amount', 'total_discount', 'amount_in_words', 'account_number', 'ifsc_code', 'trust_score']
        writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
        writer.writeheader()
        invoice_files = glob.glob(os.path.join(directory, '*.pdf'))
        for file in invoice_files:
            text_content = extract_text_from_pdf(file)
            fields = extract_fields(text_content)
            trust_score = determine_trust(fields)
            fields['file'] = os.path.basename(file)
            fields['trust_score'] = trust_score
            writer.writerow(fields)
            print(f"File: {file}")
            print(f"Extracted Fields: {fields}")
            print(f"Trust Score: {trust_score}%")
            print("=" * 40)

# %%
# Directory containing invoice PDFs and output CSV file path
invoice_directory = '/kaggle/input/jan-to-may/Jan to Mar'
output_csv_path = '/kaggle/working/zolvit_invoice_report.csv'
generate_report(invoice_directory, output_csv_path)
# Out:
# File: /kaggle/input/jan-to-may/Jan to Mar/INV-145_Indraja Mohite.pdf
# Extracted Fields: {'invoice_number': 'INV-145', 'invoice_date': '28 Mar 2024', 'taxable_value': '1,917.86', 'sgst_amount': '111.47', 'cgst_amount': '111.47', 'igst_amount': '', 'sgst_rate': '6.0', 'cgst_rate': '6.0', 'igst_rate': '', 'tax_amount': '', 'tax_rate': '', 'final_amount': '2,141.00', 'place_of_supply': '23-MADHYA PRADESH', 'place_of_origin': '23-Madhya Pradesh', 'gstin_supplier': '23AADCU2395N1ZY', 'gstin_recipient': '', 'file': 'INV-145_Indraja Mohite.pdf', 'trust_score': 100.0}
# Trust Score: 100.0%
# ========================================
# File: /kaggle/input/jan-to-may/Jan to Mar/INV-142_Urmila Jangam.pdf
# Extracted Fields: {'invoice_number': 'INV-142', 'invoice_date': '07 Mar 2024', 'taxable_value': '874.58', 'sgst_amount': '78.71', 'cgst_amount': '78.71', 'igst_amount': '', 'sgst_rate': '9.0', 'cgst_rate': '9.0', 'igst_rate': '', 'tax_amount': '', 'tax_rate': '', 'final_amount': '1,032.00', 'place_of_supply': '23-MADHYA PRADESH', 'place_of_origin': '23-Madhya Pradesh', 'gstin_supplier': '23AADCU2395N1ZY', 'gstin_recipient': '', 'file': 'INV-142_Urmila Jangam.pdf', 'trust_score': 100.0}
# Trust Score: 100.0%
# ========================================
# File: /kaggle/input/jan-to-may/Jan to Mar/INV-123_Asit.pdf
# Extracted Fields: {'invoice_number': 'INV-123', 'invoice_date': '08 Feb 2024', 'taxable_value': '990.46', 'sgst_amount': '53.92', 'cgst_amount': '53.92', 'igst_amount': '', 'sgst_rate': '6.0', 'cgst_rate': '6.0', 'igst_rate': '', 'tax_amount': '', 'tax_rate': '', 'final_amount': '1,115.00', 'place_of_supply': '23-MADHYA PRADESH', 'place_of_origin': '23-Madhya Pradesh', 'gstin_supplier': '23AADCU2395N1ZY', 'gstin_recipient': '', 'file': 'INV-123_Asit.pdf', 'trust_score': 100.0}
# Trust Score: 100.0%
# ========================================
# File: /kaggle/input/jan-to-may/Jan to Mar/INV-128_Atia Latif.pdf
# Extracted Fields: {'invoice_number': 'INV-128', 'invoice_date': '23 Feb 2024', 'taxable_value': '2,076.27', 'sgst_amount': '186.86', 'cgst_amount': '186.86', 'igst_amount': '', 'sgst_rate': '9.0', 'cgst_rate': '9.0', 'igst_rate': '', 'tax_amount': '', 'tax_rate': '', 'final_amount': '2,450.00', 'place_of_supply': '23-MADHYA PRADESH', 'place_of_origin': '23-Madhya Pradesh', 'gstin_supplier': '23AADCU2395N1ZY', 'gstin_recipient': '', 'file': 'INV-128_Atia Latif.pdf', 'trust_score': 100.0}
# Trust Score: 100.0%
# ========================================
# File: /kaggle/input/jan-to-may/Jan to Mar/INV-144_Atia Latif.pdf
# Extracted Fields: {'invoice_number': 'INV-144', 'invoice_date': '28 Mar 2024', 'taxable_value': '21,914.71', 'sgst_amount': '731.95', 'cgst_amount': '731.95', 'igst_amount': '', 'sgst_rate': '6.0', 'cgst_rate': '6.0', 'igst_rate': '', 'tax_amount': '', 'tax_rate': '', 'final_amount': '24,047.00', 'place_of_supply': '23-MADHYA PRADESH', 'place_of_origin': '23-Madhya Pradesh', 'gstin_supplier': '23AADCU2395N1ZY', 'gstin_recipient': '', 'file': 'INV-144_Atia Latif.pdf', 'trust_score': 100.0}
# Trust Score: 100.0%
# ========================================
# File: /kaggle/input/jan-to-may/Jan to Mar/INV-143_Prashant.pdf
# Extracted Fields: {'invoice_number': 'INV-143', 'invoice_date': '28 Mar 2024', 'taxable_value': '6,563.98', 'sgst_amount': '133.50', 'cgst_amount': '133.50', 'igst_amount': '', 'sgst_rate': '6.0', 'cgst_rate': '6.0', 'igst_rate': '', 'tax_amount': '', 'tax_rate': '', 'final_amount': '7,612.00', 'place_of_supply': '23-MADHYA PRADESH', 'place_of_origin': '23-Madhya Pradesh', 'gstin_supplier': '23AADCU2395N1ZY', 'gstin_recipient': '', 'file': 'INV-143_Prashant.pdf', 'trust_score': 100.0}
# Trust Score: 100.0%
# ========================================
# File: /kaggle/input/jan-to-may/Jan to Mar/INV-121_Jitesh Soni.pdf
# Extracted Fields: {'invoice_number': 'INV-121', 'invoice_date': '29 Jan 2024', 'taxable_value': '870.93', 'sgst_amount': '', 'cgst_amount': '', 'igst_amount': '34.72', 'sgst_rate': '', 'cgst_rate': '', 'igst_rate': '12.0', 'tax_amount': '', 'tax_rate': '', 'final_amount': '1,010.00', 'place_of_supply': '27-MAHARASHTRA ', 'place_of_origin': '23-Madhya Pradesh', 'gstin_supplier': '23AADCU2395N1ZY', 'gstin_recipient': '', 'file': 'INV-121_Jitesh Soni.pdf', 'trust_score': 100.0}
# Trust Score: 100.0%
# ========================================
# File: /kaggle/input/jan-to-may/Jan to Mar/INV-138_Agrani Kandele.pdf
# Extracted Fields: {'invoice_number': 'INV-138', 'invoice_date': '06 Mar 2024', 'taxable_value': '1,275.34', 'sgst_amount': '114.78', 'cgst_amount': '114.78', 'igst_amount': '', 'sgst_rate': '9.0', 'cgst_rate': '9.0', 'igst_rate': '', 'tax_amount': '', 'tax_rate': '', 'final_amount': '1,505.00', 'place_of_supply': '23-MADHYA PRADESH', 'place_of_origin': '23-Madhya Pradesh', 'gstin_supplier': '23AADCU2395N1ZY', 'gstin_recipient': '', 'file': 'INV-138_Agrani Kandele.pdf', 'trust_score': 100.0}
# Trust Score: 100.0%
# ========================================
# File: /kaggle/input/jan-to-may/Jan to Mar/INV-147_Divya Suhane.pdf
# Extracted Fields: {'invoice_number': 'INV-147', 'invoice_date': '29 Mar 2024', 'taxable_value': '3,746.82', 'sgst_amount': '12.23', 'cgst_amount': '12.23', 'igst_amount': '', 'sgst_rate': '2.5', 'cgst_rate': '2.5', 'igst_rate': '', 'tax_amount': '', 'tax_rate': '', 'final_amount': '4,015.00', 'place_of_supply': '23-MADHYA PRADESH', 'place_of_origin': '23-Madhya Pradesh', 'gstin_supplier': '23AADCU2395N1ZY', 'gstin_recipient': '', 'file': 'INV-147_Divya Suhane.pdf', 'trust_score': 100.0}
# Trust Score: 100.0%
# ========================================
# File: /kaggle/input/jan-to-may/Jan to Mar/INV-149_Karishma Bande.pdf
# Extracted Fields: {'invoice_number': 'INV-149', 'invoice_date': '22 Mar 2024', 'taxable_value': '370.64', 'sgst_amount': '33.36', 'cgst_amount': '33.36', 'igst_amount': '', 'sgst_rate': '9.0', 'cgst_rate': '9.0', 'igst_rate': '', 'tax_amount': '', 'tax_rate': '', 'final_amount': '437.00', 'place_of_supply': '23-MADHYA PRADESH', 'place_of_origin': '23-Madhya Pradesh', 'gstin_supplier': '23AADCU2395N1ZY', 'gstin_recipient': '', 'file': 'INV-149_Karishma Bande.pdf', 'trust_score': 100.0}
# Trust Score: 100.0%
# ========================================
# File: /kaggle/input/jan-to-may/Jan to Mar/INV-133_Sheetal Kapur.pdf
# Extracted Fields: {'invoice_number': 'INV-133', 'invoice_date': '01 Mar 2024', 'taxable_value': '2,302.15', 'sgst_amount': '14.61', 'cgst_amount': '14.61', 'igst_amount': '', 'sgst_rate': '6.0', 'cgst_rate': '6.0', 'igst_rate': '', 'tax_amount': '', 'tax_rate': '', 'final_amount': '2,702.00', 'place_of_supply': '23-MADHYA PRADESH', 'place_of_origin': '23-Madhya Pradesh', 'gstin_supplier': '23AADCU2395N1ZY', 'gstin_recipient': '', 'file': 'INV-133_Sheetal Kapur.pdf', 'trust_score': 100.0}
# Trust Score: 100.0%
# ========================================
# File: /kaggle/input/jan-to-may/Jan to Mar/INV-124_Ankita Sattva.pdf
# Extracted Fields: {'invoice_number': 'INV-124', 'invoice_date': '10 Feb 2024', 'taxable_value': '1,125.52', 'sgst_amount': '61.28', 'cgst_amount': '61.28', 'igst_amount': '', 'sgst_rate': '6.0', 'cgst_rate': '6.0', 'igst_rate': '', 'tax_amount': '', 'tax_rate': '', 'final_amount': '1,115.00', 'place_of_supply': '23-MADHYA PRADESH', 'place_of_origin': '23-Madhya Pradesh', 'gstin_supplier': '23AADCU2395N1ZY', 'gstin_recipient': '', 'file': 'INV-124_Ankita Sattva.pdf', 'trust_score': 100.0}
# Trust Score: 100.0%
# ========================================
# File: /kaggle/input/jan-to-may/Jan to Mar/INV-134_Sheetal Kapur.pdf
# Extracted Fields: {'invoice_number': 'INV-134', 'invoice_date': '01 Mar 2024', 'taxable_value': '723.77', 'sgst_amount': '65.14', 'cgst_amount': '65.14', 'igst_amount': '', 'sgst_rate': '9.0', 'cgst_rate': '9.0', 'igst_rate': '', 'tax_amount': '', 'tax_rate': '', 'final_amount': '854.00', 'place_of_supply': '23-MADHYA PRADESH', 'place_of_origin': '23-Madhya Pradesh', 'gstin_supplier': '23AADCU2395N1ZY', 'gstin_recipient': '', 'file': 'INV-134_Sheetal Kapur.pdf', 'trust_score': 100.0}
# Trust Score: 100.0%
# ========================================
# File: /kaggle/input/jan-to-may/Jan to Mar/INV-148_harshit rathore.pdf
# Extracted Fields: {'invoice_number': 'INV-148', 'invoice_date': '30 Mar 2024', 'taxable_value': '1,076.40', 'sgst_amount': '36.39', 'cgst_amount': '36.39', 'igst_amount': '', 'sgst_rate': '6.0', 'cgst_rate': '6.0', 'igst_rate': '', 'tax_amount': '', 'tax_rate': '', 'final_amount': '1,234.00', 'place_of_supply': '23-MADHYA PRADESH', 'place_of_origin': '23-Madhya Pradesh', 'gstin_supplier': '23AADCU2395N1ZY', 'gstin_recipient': '', 'file': 'INV-148_harshit rathore.pdf', 'trust_score': 100.0}
# Trust Score: 100.0%
# ========================================
# File: /kaggle/input/jan-to-may/Jan to Mar/INV-150_Bhusan Naresh.pdf
# Extracted Fields: {'invoice_number': 'INV-150', 'invoice_date': '22 Mar 2024', 'taxable_value': '394.51', 'sgst_amount': '35.51', 'cgst_amount': '35.51', 'igst_amount': '', 'sgst_rate': '9.0', 'cgst_rate': '9.0', 'igst_rate': '', 'tax_amount': '', 'tax_rate': '', 'final_amount': '466.00', 'place_of_supply': '23-MADHYA PRADESH', 'place_of_origin': '23-Madhya Pradesh', 'gstin_supplier': '23AADCU2395N1ZY', 'gstin_recipient': '', 'file': 'INV-150_Bhusan Naresh.pdf', 'trust_score': 100.0}
# Trust Score: 100.0%
# ========================================
# File: /kaggle/input/jan-to-may/Jan to Mar/INV-146_Abhikaran Jalonha.pdf
# Extracted Fields: {'invoice_number': 'INV-146', 'invoice_date': '29 Mar 2024', 'taxable_value': '3,348.16', 'sgst_amount': '74.31', 'cgst_amount': '74.31', 'igst_amount': '', 'sgst_rate': '6.0', 'cgst_rate': '6.0', 'igst_rate': '', 'tax_amount': '', 'tax_rate': '', 'final_amount': '3,877.00', 'place_of_supply': '23-MADHYA PRADESH', 'place_of_origin': '23-Madhya Pradesh', 'gstin_supplier': '23AADCU2395N1ZY', 'gstin_recipient': '', 'file': 'INV-146_Abhikaran Jalonha.pdf', 'trust_score': 100.0}
# Trust Score: 100.0%
# ========================================
# File: /kaggle/input/jan-to-may/Jan to Mar/INV-127_Avik Mallick.pdf
# Extracted Fields: {'invoice_number': 'INV-127', 'invoice_date': '23 Feb 2024', 'taxable_value': '943.77', 'sgst_amount': '', 'cgst_amount': '', 'igst_amount': '', 'sgst_rate': '', 'cgst_rate': '', 'igst_rate': '', 'tax_amount': '', 'tax_rate': '', 'final_amount': '944.00', 'place_of_supply': '23-MADHYA PRADESH', 'place_of_origin': '23-Madhya Pradesh', 'gstin_supplier': '23AADCU2395N1ZY', 'gstin_recipient': '', 'file': 'INV-127_Avik Mallick.pdf', 'trust_score': 100.0}
# Trust Score: 100.0%
# ========================================
# File: /kaggle/input/jan-to-may/Jan to Mar/INV-135_Mohith Saragur.pdf
# Extracted Fields: {'invoice_number': 'INV-135', 'invoice_date': '01 Mar 2024', 'taxable_value': '691.22', 'sgst_amount': '22.19', 'cgst_amount': '22.19', 'igst_amount': '', 'sgst_rate': '6.0', 'cgst_rate': '6.0', 'igst_rate': '', 'tax_amount': '', 'tax_rate': '', 'final_amount': '793.00', 'place_of_supply': '23-MADHYA PRADESH', 'place_of_origin': '23-Madhya Pradesh', 'gstin_supplier': '23AADCU2395N1ZY', 'gstin_recipient': '', 'file': 'INV-135_Mohith Saragur.pdf', 'trust_score': 100.0}
# Trust Score: 100.0%
# ========================================
# File: /kaggle/input/jan-to-may/Jan to Mar/INV-136_Rishabh Ramola.pdf
# Extracted Fields: {'invoice_number': 'INV-136', 'invoice_date': '15 Feb 2024', 'taxable_value': '961.36', 'sgst_amount': '86.52', 'cgst_amount': '86.52', 'igst_amount': '', 'sgst_rate': '9.0', 'cgst_rate': '9.0', 'igst_rate': '', 'tax_amount': '', 'tax_rate': '', 'final_amount': '1,134.00', 'place_of_supply': '23-MADHYA PRADESH', 'place_of_origin': '23-Madhya Pradesh', 'gstin_supplier': '23AADCU2395N1ZY', 'gstin_recipient': '', 'file': 'INV-136_Rishabh Ramola.pdf', 'trust_score': 100.0}
# Trust Score: 100.0%
# ========================================
# File: /kaggle/input/jan-to-may/Jan to Mar/INV-129_Divya Suhane.pdf
# Extracted Fields: {'invoice_number': 'INV-129', 'invoice_date': '23 Feb 2024', 'taxable_value': '1,117.05', 'sgst_amount': '50.91', 'cgst_amount': '50.91', 'igst_amount': '', 'sgst_rate': '6.0', 'cgst_rate': '6.0', 'igst_rate': '', 'tax_amount': '', 'tax_rate': '', 'final_amount': '1,267.00', 'place_of_supply': '23-MADHYA PRADESH', 'place_of_origin': '23-Madhya Pradesh', 'gstin_supplier': '23AADCU2395N1ZY', 'gstin_recipient': '', 'file': 'INV-129_Divya Suhane.pdf', 'trust_score': 100.0}
# Trust Score: 100.0%
# ========================================
# File: /kaggle/input/jan-to-may/Jan to Mar/INV-117_Naman.pdf
# Extracted Fields: {'invoice_number': 'INV-117', 'invoice_date': '01 Feb 2024', 'taxable_value': '1,483.32', 'sgst_amount': '83.50', 'cgst_amount': '83.50', 'igst_amount': '', 'sgst_rate': '6.0', 'cgst_rate': '6.0', 'igst_rate': '', 'tax_amount': '', 'tax_rate': '', 'final_amount': '1,667.00', 'place_of_supply': '23-MADHYA PRADESH', 'place_of_origin': '23-Madhya Pradesh', 'gstin_supplier': '23AADCU2395N1ZY', 'gstin_recipient': '', 'file': 'INV-117_Naman.pdf', 'trust_score': 100.0}
# Trust Score: 100.0%
# ========================================
# File: /kaggle/input/jan-to-may/Jan to Mar/INV-118_Rashu.pdf
# Extracted Fields: {'invoice_number': 'INV-118', 'invoice_date': '30 Jan 2024', 'taxable_value': '350.00', 'sgst_amount': '', 'cgst_amount': '', 'igst_amount': '', 'sgst_rate': '', 'cgst_rate': '', 'igst_rate': '', 'tax_amount': '', 'tax_rate': '', 'final_amount': '350.00', 'place_of_supply': '23-MADHYA PRADESH', 'place_of_origin': '23-Madhya Pradesh', 'gstin_supplier': '23AADCU2395N1ZY', 'gstin_recipient': '', 'file': 'INV-118_Rashu.pdf', 'trust_score': 100.0}
# Trust Score: 100.0%
# ========================================
# File: /kaggle/input/jan-to-may/Jan to Mar/INV-140_Ankit.pdf
# Extracted Fields: {'invoice_number': 'INV-140', 'invoice_date': '06 Mar 2024', 'taxable_value': '999.36', 'sgst_amount': '31.28', 'cgst_amount': '31.28', 'igst_amount': '', 'sgst_rate': '6.0', 'cgst_rate': '6.0', 'igst_rate': '', 'tax_amount': '', 'tax_rate': '', 'final_amount': '1,148.00', 'place_of_supply': '23-MADHYA PRADESH', 'place_of_origin': '23-Madhya Pradesh', 'gstin_supplier': '23AADCU2395N1ZY', 'gstin_recipient': '', 'file': 'INV-140_Ankit.pdf', 'trust_score': 100.0}
# Trust Score: 100.0%
# ========================================
# File: /kaggle/input/jan-to-may/Jan to Mar/INV-141_Kasturi Kalwar.pdf
# Extracted Fields: {'invoice_number': 'INV-141', 'invoice_date': '06 Mar 2024', 'taxable_value': '1,486.02', 'sgst_amount': '133.74', 'cgst_amount': '133.74', 'igst_amount': '', 'sgst_rate': '9.0', 'cgst_rate': '9.0', 'igst_rate': '', 'tax_amount': '', 'tax_rate': '', 'final_amount': '1,754.00', 'place_of_supply': '23-MADHYA PRADESH', 'place_of_origin': '23-Madhya Pradesh', 'gstin_supplier': '23AADCU2395N1ZY', 'gstin_recipient': '', 'file': 'INV-141_Kasturi Kalwar.pdf', 'trust_score': 100.0}
# Trust Score: 100.0%
# ========================================

# %%
import pandas as pd

# %%
df = pd.read_csv("/kaggle/working/zolvit_invoice_report.csv")
# Replace NaN values with empty strings
df = df.fillna('')
df
# Out:
#                              file taxable_value sgst_amount cgst_amount  \
# 0      INV-145_Indraja Mohite.pdf      1,917.86      111.47      111.47
# 1       INV-142_Urmila Jangam.pdf        874.58       78.71       78.71
# 2                INV-123_Asit.pdf        990.46       53.92       53.92
# 3          INV-128_Atia Latif.pdf      2,076.27      186.86      186.86
# 4          INV-144_Atia Latif.pdf     21,914.71      731.95      731.95
# 5            INV-143_Prashant.pdf      6,563.98       133.5       133.5
# 6         INV-121_Jitesh Soni.pdf        870.93
# 7      INV-138_Agrani Kandele.pdf      1,275.34      114.78      114.78
# 8        INV-147_Divya Suhane.pdf      3,746.82       12.23       12.23
# 9      INV-149_Karishma Bande.pdf        370.64       33.36       33.36
# 10      INV-133_Sheetal Kapur.pdf      2,302.15       14.61       14.61
# 11      INV-124_Ankita Sattva.pdf      1,125.52       61.28       61.28
# 12      INV-134_Sheetal Kapur.pdf        723.77       65.14       65.14
# 13    INV-148_harshit rathore.pdf      1,076.40       36.39       36.39
# 14      INV-150_Bhusan Naresh.pdf        394.51       35.51       35.51
# 15  INV-146_Abhikaran Jalonha.pdf      3,348.16       74.31       74.31
# 16       INV-127_Avik Mallick.pdf        943.77
# 17     INV-135_Mohith Saragur.pdf        691.22       22.19       22.19
# 18     INV-136_Rishabh Ramola.pdf        961.36       86.52       86.52
# 19       INV-129_Divya Suhane.pdf      1,117.05       50.91       50.91
# 20              INV-117_Naman.pdf      1,483.32        83.5        83.5
# 21              INV-118_Rashu.pdf        350.00
# 22              INV-140_Ankit.pdf        999.36       31.28       31.28
# 23     INV-141_Kasturi Kalwar.pdf      1,486.02      133.74      133.74
#
#    igst_amount sgst_rate cgst_rate igst_rate tax_amount tax_rate final_amount  \
# 0                    6.0       6.0                                   2,141.00
# 1                    9.0       9.0                                   1,032.00
# 2                    6.0       6.0                                   1,115.00
# 3                    9.0       9.0                                   2,450.00
# 4                    6.0       6.0                                  24,047.00
# 5                    6.0       6.0                                   7,612.00
# 6        34.72                          12.0                         1,010.00
# 7                    9.0       9.0                                   1,505.00
# 8                    2.5       2.5                                   4,015.00
# 9                    9.0       9.0                                     437.00
# 10                   6.0       6.0                                   2,702.00
# 11                   6.0       6.0                                   1,115.00
# 12                   9.0       9.0                                     854.00
# 13                   6.0       6.0                                   1,234.00
# 14                   9.0       9.0                                     466.00
# 15                   6.0       6.0                                   3,877.00
# 16                                                                     944.00
# 17                   6.0       6.0                                     793.00
# 18                   9.0       9.0                                   1,134.00
# 19                   6.0       6.0                                   1,267.00
# 20                   6.0       6.0                                   1,667.00
# 21                                                                     350.00
# 22                   6.0       6.0                                   1,148.00
# 23                   9.0       9.0                                   1,754.00
#
#    invoice_number invoice_date    place_of_supply    place_of_origin  \
# 0         INV-145  28 Mar 2024  23-MADHYA PRADESH  23-Madhya Pradesh
# 1         INV-142  07 Mar 2024  23-MADHYA PRADESH  23-Madhya Pradesh
# 2         INV-123  08 Feb 2024  23-MADHYA PRADESH  23-Madhya Pradesh
# 3         INV-128  23 Feb 2024  23-MADHYA PRADESH  23-Madhya Pradesh
# 4         INV-144  28 Mar 2024  23-MADHYA PRADESH  23-Madhya Pradesh
# 5         INV-143  28 Mar 2024  23-MADHYA PRADESH  23-Madhya Pradesh
# 6         INV-121  29 Jan 2024    27-MAHARASHTRA   23-Madhya Pradesh
# 7         INV-138  06 Mar 2024  23-MADHYA PRADESH  23-Madhya Pradesh
# 8         INV-147  29 Mar 2024  23-MADHYA PRADESH  23-Madhya Pradesh
# 9         INV-149  22 Mar 2024  23-MADHYA PRADESH  23-Madhya Pradesh
# 10        INV-133  01 Mar 2024  23-MADHYA PRADESH  23-Madhya Pradesh
# 11        INV-124  10 Feb 2024  23-MADHYA PRADESH  23-Madhya Pradesh
# 12        INV-134  01 Mar 2024  23-MADHYA PRADESH  23-Madhya Pradesh
# 13        INV-148  30 Mar 2024  23-MADHYA PRADESH  23-Madhya Pradesh
# 14        INV-150  22 Mar 2024  23-MADHYA PRADESH  23-Madhya Pradesh
# 15        INV-146  29 Mar 2024  23-MADHYA PRADESH  23-Madhya Pradesh
# 16        INV-127  23 Feb 2024  23-MADHYA PRADESH  23-Madhya Pradesh
# 17        INV-135  01 Mar 2024  23-MADHYA PRADESH  23-Madhya Pradesh
# 18        INV-136  15 Feb 2024  23-MADHYA PRADESH  23-Madhya Pradesh
# 19        INV-129  23 Feb 2024  23-MADHYA PRADESH  23-Madhya Pradesh
# 20        INV-117  01 Feb 2024  23-MADHYA PRADESH  23-Madhya Pradesh
# 21        INV-118  30 Jan 2024  23-MADHYA PRADESH  23-Madhya Pradesh
# 22        INV-140  06 Mar 2024  23-MADHYA PRADESH  23-Madhya Pradesh
# 23        INV-141  06 Mar 2024  23-MADHYA PRADESH  23-Madhya Pradesh
#
#      gstin_supplier gstin_recipient  trust_score
# 0   23AADCU2395N1ZY                        100.0
# 1   23AADCU2395N1ZY                        100.0
# 2   23AADCU2395N1ZY                        100.0
# 3   23AADCU2395N1ZY                        100.0
# 4   23AADCU2395N1ZY                        100.0
# 5   23AADCU2395N1ZY                        100.0
# 6   23AADCU2395N1ZY                        100.0
# 7   23AADCU2395N1ZY                        100.0
# 8   23AADCU2395N1ZY                        100.0
# 9   23AADCU2395N1ZY                        100.0
# 10  23AADCU2395N1ZY                        100.0
# 11  23AADCU2395N1ZY                        100.0
# 12  23AADCU2395N1ZY                        100.0
# 13  23AADCU2395N1ZY                        100.0
# 14  23AADCU2395N1ZY                        100.0
# 15  23AADCU2395N1ZY                        100.0
# 16  23AADCU2395N1ZY                        100.0
# 17  23AADCU2395N1ZY                        100.0
# 18  23AADCU2395N1ZY                        100.0
# 19  23AADCU2395N1ZY                        100.0
# 20  23AADCU2395N1ZY                        100.0
# 21  23AADCU2395N1ZY                        100.0
# 22  23AADCU2395N1ZY                        100.0
# 23  23AADCU2395N1ZY                        100.0

# %%
fieldnames = ['taxable_value', 'sgst_amount', 'cgst_amount', 'igst_amount', 'sgst_rate', 'cgst_rate',
              'igst_rate', 'tax_amount', 'tax_rate', 'final_amount','invoice_number', 'invoice_date',
              'place_of_supply', 'place_of_origin', 'gstin_supplier', 'gstin_recipient']

# %%
'account_number': lambda x: bool(re.match(r'^\d+$', x)) if x else False,
        'ifsc_code': lambda x: bool(re.match(r'^[A-Za-z]{4}0[A-Za-z0-9]{6}$', x)) if x else False
